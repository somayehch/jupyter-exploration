# %%
print("Hello, Jupyter! ")
# Out:
# Hello, Jupyter!

# %% [markdown]
# # My Jupyter Exploration
# This is where I practice coding, write notes, and explore new ideas step by step.

# %%
print("Keep going, every small step matters.")
# Out:
# Keep going, every small step matters.

# %% [markdown]
# # Motivational Notes 🌟
#
# > "The expert in anything was once a beginner." – Helen Hayes
#
# > "Do not wait to strike till the iron is hot; but make it hot by striking." – William Butler Yeats
#
# > "Learning never exhausts the mind." – Leonardo da Vinci
#
# ---
# This notebook is a space to practice coding, add ideas, and reflect on progress.

# %% [markdown]
# ---
#
# ## 🌟 Final Thoughts
#
# > "The expert in anything was once a beginner." – Helen Hayes
#
# > "Little by little, one travels far." – J.R.R. Tolkien
#
# > "Your only limit is your mind." – Unknown
